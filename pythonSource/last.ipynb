# %%
# K-Means Clustering

# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
# Importing the dataset
#dataset = pd.read_csv(r'C:\Users\Ravi\Desktop\Music Recommendation System\music.csv')

dataset = pd.read_csv(r'C:\Users\Ravi\Desktop\SpotifyAudio.csv')

# y = dataset.iloc[:, 3].values

# dataset exploring
print(dataset.columns)

# Print the shape of the data
dataset = dataset.sample(frac=0.1, random_state = 1)
print(dataset.shape)
print(dataset.describe())

# V1 - V28 are the results of a PCA Dimensionality reduction to protect user identities and sensitive features

# Plot histograms of each parameter 
dataset.hist(figsize = (20, 20))
plt.show()
#plt.savefig('p1.png')
# Out:
# Index(['artist_name', 'track_id', 'track_name', 'acousticness', 'danceability',
#        'duration_ms', 'energy', 'instrumentalness', 'key', 'liveness',
#        'loudness', 'mode', 'speechiness', 'tempo', 'time_signature', 'valence',
#        'popularity'],
#       dtype='object')
# (13066, 17)
#        acousticness  danceability   duration_ms        energy  \
# count  13066.000000  13066.000000  1.306600e+04  13066.000000
# mean       0.342462      0.582968  2.113831e+05      0.568530
# std        0.343708      0.188550  1.062162e+05      0.257989
# min        0.000000      0.000000  9.787000e+03      0.000000
# 25%        0.031600      0.460250  1.634850e+05      0.399000
# 50%        0.208000      0.610000  2.018600e+05      0.598000
# 75%        0.636750      0.726000  2.407275e+05      0.772000
# max        0.996000      0.985000  2.770500e+06      1.000000
#
#        instrumentalness           key      liveness      loudness  \
# count      13066.000000  13066.000000  13066.000000  13066.000000
# mean           0.221309      5.249809      0.193277     -9.966749
# std            0.359177      3.586754      0.165083      6.541734
# min            0.000000      0.000000      0.000000    -60.000000
# 25%            0.000000      2.000000      0.097800    -11.809750
# 50%            0.000134      5.000000      0.124000     -8.015000
# 75%            0.424750      8.000000      0.231000     -5.696000
# max            1.000000     11.000000      0.992000      0.494000
#
#                mode   speechiness         tempo  time_signature       valence  \
# count  13066.000000  13066.000000  13066.000000    13066.000000  13066.000000
# mean       0.610975      0.111526    119.197691        3.884586      0.438546
# std        0.487548      0.123484     29.918222        0.503790      0.258103
# min        0.000000      0.000000      0.000000        0.000000      0.000000
# 25%        0.000000      0.038800     95.999000        4.000000      0.223000
# 50%        1.000000      0.056100    120.009000        4.000000      0.419000
# 75%        1.000000      0.127750    138.899000        4.000000      0.639000
# max        1.000000      0.957000    249.983000        5.000000      1.000000
#
#          popularity
# count  13066.000000
# mean      24.319914
# std       19.931100
# min        0.000000
# 25%        7.000000
# 50%       21.000000
# 75%       38.000000
# max       98.000000

# %%
X = dataset.iloc[:, [3,4]].values
# Splitting the dataset into the Training set and Test set
"""from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)"""

# Feature Scaling
"""from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)
sc_y = StandardScaler()
y_train = sc_y.fit_transform(y_train)"""

# Using the elbow method to find the optimal number of clusters
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# Fitting K-Means to the dataset
kmeans = KMeans(n_clusters = 5, init = 'k-means++', random_state = 42)
y_kmeans = kmeans.fit_predict(X)

# Visualising the clusters
plt.scatter(X[y_kmeans == 0, 0], X[y_kmeans == 0, 1], s = 5, c = 'red', label = 'Cluster 1')
plt.scatter(X[y_kmeans == 1, 0], X[y_kmeans == 1, 1], s = 5, c = 'blue', label = 'Cluster 2')
plt.scatter(X[y_kmeans == 2, 0], X[y_kmeans == 2, 1], s = 5, c = 'green', label = 'Cluster 3')
plt.scatter(X[y_kmeans == 3, 0], X[y_kmeans == 3, 1], s = 5, c = 'cyan', label = 'Cluster 4')
plt.scatter(X[y_kmeans == 4, 0], X[y_kmeans == 4, 1], s = 5, c = 'magenta', label = 'Cluster 5')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 300, c = 'yellow', label = 'Centroids')
plt.title('Clusters of accoustiness vs danceability')
plt.xlabel('accoustiness')
plt.ylabel('dancebility')
plt.legend()
plt.show()

# %%
X = dataset.iloc[:, [6,7]].values
# Splitting the dataset into the Training set and Test set
"""from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)"""

# Feature Scaling
"""from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)
sc_y = StandardScaler()
y_train = sc_y.fit_transform(y_train)"""

# Using the elbow method to find the optimal number of clusters
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# Fitting K-Means to the dataset
kmeans = KMeans(n_clusters = 5, init = 'k-means++', random_state = 42)
y_kmeans = kmeans.fit_predict(X)

# Visualising the clusters
plt.scatter(X[y_kmeans == 0, 0], X[y_kmeans == 0, 1], s = 5, c = 'red', label = 'Cluster 1')
plt.scatter(X[y_kmeans == 1, 0], X[y_kmeans == 1, 1], s = 5, c = 'blue', label = 'Cluster 2')
plt.scatter(X[y_kmeans == 2, 0], X[y_kmeans == 2, 1], s = 5, c = 'green', label = 'Cluster 3')
plt.scatter(X[y_kmeans == 3, 0], X[y_kmeans == 3, 1], s = 5, c = 'cyan', label = 'Cluster 4')
plt.scatter(X[y_kmeans == 4, 0], X[y_kmeans == 4, 1], s = 5, c = 'magenta', label = 'Cluster 5')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 300, c = 'yellow', label = 'Centroids')
plt.title('Clusters of accoustiness vs danceability')
plt.xlabel('energy')
plt.ylabel('instrumental')
plt.legend()
plt.show()

# %%
X = dataset.iloc[:, [9,10]].values
# Splitting the dataset into the Training set and Test set
"""from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)"""

# Feature Scaling
"""from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)
sc_y = StandardScaler()
y_train = sc_y.fit_transform(y_train)"""

# Using the elbow method to find the optimal number of clusters
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# Fitting K-Means to the dataset
kmeans = KMeans(n_clusters = 5, init = 'k-means++', random_state = 42)
y_kmeans = kmeans.fit_predict(X)

# Visualising the clusters
plt.scatter(X[y_kmeans == 0, 0], X[y_kmeans == 0, 1], s = 5, c = 'red', label = 'Cluster 1')
plt.scatter(X[y_kmeans == 1, 0], X[y_kmeans == 1, 1], s = 5, c = 'blue', label = 'Cluster 2')
plt.scatter(X[y_kmeans == 2, 0], X[y_kmeans == 2, 1], s = 5, c = 'green', label = 'Cluster 3')
plt.scatter(X[y_kmeans == 3, 0], X[y_kmeans == 3, 1], s = 5, c = 'cyan', label = 'Cluster 4')
plt.scatter(X[y_kmeans == 4, 0], X[y_kmeans == 4, 1], s = 5, c = 'magenta', label = 'Cluster 5')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 300, c = 'yellow', label = 'Centroids')
plt.title('Clusters of accoustiness vs danceability')
plt.xlabel('liveness')
plt.ylabel('loudness')
plt.legend()
plt.show()

# %%
X = dataset.iloc[:, [12,15]].values
# Splitting the dataset into the Training set and Test set
"""from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)"""

# Feature Scaling
"""from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)
sc_y = StandardScaler()
y_train = sc_y.fit_transform(y_train)"""

# Using the elbow method to find the optimal number of clusters
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# Fitting K-Means to the dataset
kmeans = KMeans(n_clusters = 5, init = 'k-means++', random_state = 42)
y_kmeans = kmeans.fit_predict(X)

# Visualising the clusters
plt.scatter(X[y_kmeans == 0, 0], X[y_kmeans == 0, 1], s = 5, c = 'red', label = 'Cluster 1')
plt.scatter(X[y_kmeans == 1, 0], X[y_kmeans == 1, 1], s = 5, c = 'blue', label = 'Cluster 2')
plt.scatter(X[y_kmeans == 2, 0], X[y_kmeans == 2, 1], s = 5, c = 'green', label = 'Cluster 3')
plt.scatter(X[y_kmeans == 3, 0], X[y_kmeans == 3, 1], s = 5, c = 'cyan', label = 'Cluster 4')
plt.scatter(X[y_kmeans == 4, 0], X[y_kmeans == 4, 1], s = 5, c = 'magenta', label = 'Cluster 5')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 300, c = 'yellow', label = 'Centroids')
plt.title('Clusters of accoustiness vs danceability')
plt.xlabel('speechness')
plt.ylabel('valence')
plt.legend()
plt.show()

# %%
musicdata = dataset.pivot_table(index = 'artist_name',columns = 'track_name',values='popularity')

# %%
musicdata
# Out:
# track_name              "42" - From SR3MM  \
# artist_name
# !!!                                   NaN
# "Elena Of Avalor" Cast                NaN
# "Weird Al" Yankovic                   NaN
# $hirak                                NaN
# $tranger                              NaN
# $tupid Young                          NaN
# $uicideBoy$                           NaN
# (G)I-DLE                              NaN
# .anxious.                             NaN
# 03 Greedo                             NaN
# 070 Shake                             NaN
# 100Gang                               NaN
# 10cellphones                          NaN
# 116                                   NaN
# 12Stone Worship                       NaN
# 13 Block                              NaN
# 13 Crowns                             NaN
# 1:AM Beats                            NaN
# 1Kilo                                 NaN
# 1ST VOWS                              NaN
# 2 Chainz                              NaN
# 2 Face T.R.E.                         NaN
# 2 Mello                               NaN
# 20 Years of Age                       NaN
# 21 Days                               NaN
# 21 Savage                             NaN
# 24hrs                                 NaN
# 28mm                                  NaN
# 2BiC                                  NaN
# 2SCOOPS                               NaN
# ...                                   ...
# Антон Беляев                          NaN
# Григорий Лепс                         NaN
# Дельфин                               NaN
# Джиган                                NaN
# Кино                                  NaN
# Кровосток                             NaN
# Ленинград                             NaN
# Макс Барских                          NaN
# Мари Краймбрери                       NaN
# Михаил Шуфутинский                    NaN
# Миша Марвин                           NaN
# Мот                                   NaN
# Мохито                                NaN
# Нюша                                  NaN
# Эллаи                                 NaN
# тпсб                                  NaN
# 侯英祚                                   NaN
# 湊貴大(流星P)                              NaN
# 緑                                     NaN
# 霍尊                                    NaN
# 니하고내하고                                NaN
# 박재정                                   NaN
# 범키                                    NaN
# 스텔라장                                  NaN
# 유나                                    NaN
# 유닛플러스                                 NaN
# 임정희                                   NaN
# 장재인                                   NaN
# 하동균                                   NaN
# ＮＯＳＴＲＡＤＡＭＵＳ                           NaN
#
# track_name              "Petit Quatuor" en Ut Majeur, CG 561: I. Adagio - Allegro moderato  \
# artist_name
# !!!                                                                   NaN
# "Elena Of Avalor" Cast                                                NaN
# "Weird Al" Yankovic                                                   NaN
# $hirak                                                                NaN
# $tranger                                                              NaN
# $tupid Young                                                          NaN
# $uicideBoy$                                                           NaN
# (G)I-DLE                                                              NaN
# .anxious.                                                             NaN
# 03 Greedo                                                             NaN
# 070 Shake                                                             NaN
# 100Gang                                                               NaN
# 10cellphones                                                          NaN
# 116                                                                   NaN
# 12Stone Worship                                                       NaN
# 13 Block                                                              NaN
# 13 Crowns                                                             NaN
# 1:AM Beats                                                            NaN
# 1Kilo                                                                 NaN
# 1ST VOWS                                                              NaN
# 2 Chainz                                                              NaN
# 2 Face T.R.E.                                                         NaN
# 2 Mello                                                               NaN
# 20 Years of Age                                                       NaN
# 21 Days                                                               NaN
# 21 Savage                                                             NaN
# 24hrs                                                                 NaN
# 28mm                                                                  NaN
# 2BiC                                                                  NaN
# 2SCOOPS                                                               NaN
# ...                                                                   ...
# Антон Беляев                                                          NaN
# Григорий Лепс                                                         NaN
# Дельфин                                                               NaN
# Джиган                                                                NaN
# Кино                                                                  NaN
# Кровосток                                                             NaN
# Ленинград                                                             NaN
# Макс Барских                                                          NaN
# Мари Краймбрери                                                       NaN
# Михаил Шуфутинский                                                    NaN
# Миша Марвин                                                           NaN
# Мот                                                                   NaN
# Мохито                                                                NaN
# Нюша                                                                  NaN
# Эллаи                                                                 NaN
# тпсб                                                                  NaN
# 侯英祚                                                                   NaN
# 湊貴大(流星P)                                                              NaN
# 緑                                                                     NaN
# 霍尊                                                                    NaN
# 니하고내하고                                                                NaN
# 박재정                                                                   NaN
# 범키                                                                    NaN
# 스텔라장                                                                  NaN
# 유나                                                                    NaN
# 유닛플러스                                                                 NaN
# 임정희                                                                   NaN
# 장재인                                                                   NaN
# 하동균                                                                   NaN
# ＮＯＳＴＲＡＤＡＭＵＳ                                                           NaN
#
# track_name              "Try It"  #NoBS  #NoJumper  #OneTake  #SayItTwice  \
# artist_name
# !!!                          NaN    NaN        NaN       NaN          NaN
# "Elena Of Avalor" Cast       NaN    NaN        NaN       NaN          NaN
# "Weird Al" Yankovic          NaN    NaN        NaN       NaN          NaN
# $hirak                       NaN    NaN        NaN       NaN          NaN
# $tranger                     NaN    NaN        NaN       NaN          NaN
# $tupid Young                 NaN    NaN        NaN       NaN          NaN
# $uicideBoy$                  NaN    NaN        NaN       NaN          NaN
# (G)I-DLE                     NaN    NaN        NaN       NaN          NaN
# .anxious.                    NaN    NaN        NaN       NaN          NaN
# 03 Greedo                    NaN    NaN        NaN       NaN          NaN
# 070 Shake                    NaN    NaN        NaN       NaN          NaN
# 100Gang                      NaN    NaN        NaN       NaN          NaN
# 10cellphones                 NaN    NaN        NaN       NaN          NaN
# 116                          NaN    NaN        NaN       NaN          NaN
# 12Stone Worship              NaN    NaN        NaN       NaN          NaN
# 13 Block                     NaN    NaN        NaN       NaN          NaN
# 13 Crowns                    NaN    NaN        NaN       NaN          NaN
# 1:AM Beats                   NaN    NaN        NaN       NaN          NaN
# 1Kilo                        NaN    NaN        NaN       NaN          NaN
# 1ST VOWS                     NaN    NaN        NaN       NaN          NaN
# 2 Chainz                     NaN    NaN        NaN       NaN          NaN
# 2 Face T.R.E.                NaN    NaN        NaN       NaN          NaN
# 2 Mello                      NaN    NaN        NaN       NaN          NaN
# 20 Years of Age              NaN    NaN        NaN       NaN          NaN
# 21 Days                      NaN    NaN        NaN       NaN          NaN
# 21 Savage                    NaN    NaN        NaN       NaN          NaN
# 24hrs                        NaN    NaN        NaN       NaN          NaN
# 28mm                         NaN    NaN        NaN       NaN          NaN
# 2BiC                         NaN    NaN        NaN       NaN          NaN
# 2SCOOPS                      NaN    NaN        NaN       NaN          NaN
# ...                          ...    ...        ...       ...          ...
# Антон Беляев                 NaN    NaN        NaN       NaN          NaN
# Григорий Лепс                NaN    NaN        NaN       NaN          NaN
# Дельфин                      NaN    NaN        NaN       NaN          NaN
# Джиган                       NaN    NaN        NaN       NaN          NaN
# Кино                         NaN    NaN        NaN       NaN          NaN
# Кровосток                    NaN    NaN        NaN       NaN          NaN
# Ленинград                    NaN    NaN        NaN       NaN          NaN
# Макс Барских                 NaN    NaN        NaN       NaN          NaN
# Мари Краймбрери              NaN    NaN        NaN       NaN          NaN
# Михаил Шуфутинский           NaN    NaN        NaN       NaN          NaN
# Миша Марвин                  NaN    NaN        NaN       NaN          NaN
# Мот                          NaN    NaN        NaN       NaN          NaN
# Мохито                       NaN    NaN        NaN       NaN          NaN
# Нюша                         NaN    NaN        NaN       NaN          NaN
# Эллаи                        NaN    NaN        NaN       NaN          NaN
# тпсб                         NaN    NaN        NaN       NaN          NaN
# 侯英祚                          NaN    NaN        NaN       NaN          NaN
# 湊貴大(流星P)                     NaN    NaN        NaN       NaN          NaN
# 緑                            NaN    NaN        NaN       NaN          NaN
# 霍尊                           NaN    NaN        NaN       NaN          NaN
# 니하고내하고                       NaN    NaN        NaN       NaN          NaN
# 박재정                          NaN    NaN        NaN       NaN          NaN
# 범키                           NaN    NaN        NaN       NaN          NaN
# 스텔라장                         NaN    NaN        NaN       NaN          NaN
# 유나                           NaN    NaN        NaN       NaN          NaN
# 유닛플러스                        NaN    NaN        NaN       NaN          NaN
# 임정희                          NaN    NaN        NaN       NaN          NaN
# 장재인                          NaN    NaN        NaN       NaN          NaN
# 하동균                          NaN    NaN        NaN       NaN          NaN
# ＮＯＳＴＲＡＤＡＭＵＳ                  NaN    NaN        NaN       NaN          NaN
#
# track_name              #WCF  #WYD - JP Ver.  #freesam  ...  \
# artist_name                                             ...
# !!!                      NaN             NaN       NaN  ...
# "Elena Of Avalor" Cast   NaN             NaN       NaN  ...
# "Weird Al" Yankovic      NaN             NaN       NaN  ...
# $hirak                   NaN             NaN       NaN  ...
# $tranger                 NaN             NaN       NaN  ...
# $tupid Young             NaN             NaN       NaN  ...
# $uicideBoy$              NaN             NaN       NaN  ...
# (G)I-DLE                 NaN             NaN       NaN  ...
# .anxious.                NaN             NaN       NaN  ...
# 03 Greedo                NaN             NaN       NaN  ...
# 070 Shake                NaN             NaN       NaN  ...
# 100Gang                  NaN             NaN       NaN  ...
# 10cellphones             NaN             NaN       NaN  ...
# 116                      NaN             NaN       NaN  ...
# 12Stone Worship          NaN             NaN       NaN  ...
# 13 Block                 NaN             NaN       NaN  ...
# 13 Crowns                NaN             NaN       NaN  ...
# 1:AM Beats               NaN             NaN       NaN  ...
# 1Kilo                    NaN             NaN       NaN  ...
# 1ST VOWS                 NaN             NaN       NaN  ...
# 2 Chainz                 NaN             NaN       NaN  ...
# 2 Face T.R.E.            NaN             NaN       NaN  ...
# 2 Mello                  NaN             NaN       NaN  ...
# 20 Years of Age          NaN             NaN       NaN  ...
# 21 Days                  NaN             NaN       NaN  ...
# 21 Savage                NaN             NaN       NaN  ...
# 24hrs                    NaN             NaN       NaN  ...
# 28mm                     NaN             NaN       NaN  ...
# 2BiC                     NaN             NaN       NaN  ...
# 2SCOOPS                  NaN             NaN       NaN  ...
# ...                      ...             ...       ...  ...
# Антон Беляев             NaN             NaN       NaN  ...
# Григорий Лепс            NaN             NaN       NaN  ...
# Дельфин                  NaN             NaN       NaN  ...
# Джиган                   NaN             NaN       NaN  ...
# Кино                     NaN             NaN       NaN  ...
# Кровосток                NaN             NaN       NaN  ...
# Ленинград                NaN             NaN       NaN  ...
# Макс Барских             NaN             NaN       NaN  ...
# Мари Краймбрери          NaN             NaN       NaN  ...
# Михаил Шуфутинский       NaN             NaN       NaN  ...
# Миша Марвин              NaN             NaN       NaN  ...
# Мот                      NaN             NaN       NaN  ...
# Мохито                   NaN             NaN       NaN  ...
# Нюша                     NaN             NaN       NaN  ...
# Эллаи                    NaN             NaN       NaN  ...
# тпсб                     NaN             NaN       NaN  ...
# 侯英祚                      NaN             NaN       NaN  ...
# 湊貴大(流星P)                 NaN             NaN       NaN  ...
# 緑                        NaN             NaN       NaN  ...
# 霍尊                       NaN             NaN       NaN  ...
# 니하고내하고                   NaN             NaN       NaN  ...
# 박재정                      NaN             NaN       NaN  ...
# 범키                       NaN             NaN       NaN  ...
# 스텔라장                     NaN             NaN       NaN  ...
# 유나                       NaN             NaN       NaN  ...
# 유닛플러스                    NaN             NaN       NaN  ...
# 임정희                      NaN             NaN       NaN  ...
# 장재인                      NaN             NaN       NaN  ...
# 하동균                      NaN             NaN       NaN  ...
# ＮＯＳＴＲＡＤＡＭＵＳ              NaN             NaN       NaN  ...
#
# track_name              사랑했다고 That You Loved Me  아픈 길 hurt road  안아줄게 Hug  \
# artist_name
# !!!                                         NaN             NaN       NaN
# "Elena Of Avalor" Cast                      NaN             NaN       NaN
# "Weird Al" Yankovic                         NaN             NaN       NaN
# $hirak                                      NaN             NaN       NaN
# $tranger                                    NaN             NaN       NaN
# $tupid Young                                NaN             NaN       NaN
# $uicideBoy$                                 NaN             NaN       NaN
# (G)I-DLE                                    NaN             NaN       NaN
# .anxious.                                   NaN             NaN       NaN
# 03 Greedo                                   NaN             NaN       NaN
# 070 Shake                                   NaN             NaN       NaN
# 100Gang                                     NaN             NaN       NaN
# 10cellphones                                NaN             NaN       NaN
# 116                                         NaN             NaN       NaN
# 12Stone Worship                             NaN             NaN       NaN
# 13 Block                                    NaN             NaN       NaN
# 13 Crowns                                   NaN             NaN       NaN
# 1:AM Beats                                  NaN             NaN       NaN
# 1Kilo                                       NaN             NaN       NaN
# 1ST VOWS                                    NaN             NaN       NaN
# 2 Chainz                                    NaN             NaN       NaN
# 2 Face T.R.E.                               NaN             NaN       NaN
# 2 Mello                                     NaN             NaN       NaN
# 20 Years of Age                             NaN             NaN       NaN
# 21 Days                                     NaN             NaN       NaN
# 21 Savage                                   NaN             NaN       NaN
# 24hrs                                       NaN             NaN       NaN
# 28mm                                        NaN             NaN       NaN
# 2BiC                                        NaN             NaN       NaN
# 2SCOOPS                                     NaN             NaN       NaN
# ...                                         ...             ...       ...
# Антон Беляев                                NaN             NaN       NaN
# Григорий Лепс                               NaN             NaN       NaN
# Дельфин                                     NaN             NaN       NaN
# Джиган                                      NaN             NaN       NaN
# Кино                                        NaN             NaN       NaN
# Кровосток                                   NaN             NaN       NaN
# Ленинград                                   NaN             NaN       NaN
# Макс Барских                                NaN             NaN       NaN
# Мари Краймбрери                             NaN             NaN       NaN
# Михаил Шуфутинский                          NaN             NaN       NaN
# Миша Марвин                                 NaN             NaN       NaN
# Мот                                         NaN             NaN       NaN
# Мохито                                      NaN             NaN       NaN
# Нюша                                        NaN             NaN       NaN
# Эллаи                                       NaN             NaN       NaN
# тпсб                                        NaN             NaN       NaN
# 侯英祚                                         NaN             NaN       NaN
# 湊貴大(流星P)                                    NaN             NaN       NaN
# 緑                                           NaN             NaN       NaN
# 霍尊                                          NaN             NaN       NaN
# 니하고내하고                                      NaN             NaN       NaN
# 박재정                                         NaN             NaN       NaN
# 범키                                          NaN             NaN       NaN
# 스텔라장                                        NaN             NaN       NaN
# 유나                                          NaN             NaN       NaN
# 유닛플러스                                       NaN             NaN       NaN
# 임정희                                         NaN             NaN       NaN
# 장재인                                         NaN             NaN       NaN
# 하동균                                         NaN             NaN       NaN
# ＮＯＳＴＲＡＤＡＭＵＳ                                 NaN             NaN       NaN
#
# track_name              열기 (9)    외투  우리 Us  우연처럼 Coincidence  텐데…Timeless  \
# artist_name
# !!!                        NaN   NaN    NaN               NaN          NaN
# "Elena Of Avalor" Cast     NaN   NaN    NaN               NaN          NaN
# "Weird Al" Yankovic        NaN   NaN    NaN               NaN          NaN
# $hirak                     NaN   NaN    NaN               NaN          NaN
# $tranger                   NaN   NaN    NaN               NaN          NaN
# $tupid Young               NaN   NaN    NaN               NaN          NaN
# $uicideBoy$                NaN   NaN    NaN               NaN          NaN
# (G)I-DLE                   NaN   NaN    NaN               NaN          NaN
# .anxious.                  NaN   NaN    NaN               NaN          NaN
# 03 Greedo                  NaN   NaN    NaN               NaN          NaN
# 070 Shake                  NaN   NaN    NaN               NaN          NaN
# 100Gang                    NaN   NaN    NaN               NaN          NaN
# 10cellphones               NaN   NaN    NaN               NaN          NaN
# 116                        NaN   NaN    NaN               NaN          NaN
# 12Stone Worship            NaN   NaN    NaN               NaN          NaN
# 13 Block                   NaN   NaN    NaN               NaN          NaN
# 13 Crowns                  NaN   NaN    NaN               NaN          NaN
# 1:AM Beats                 NaN   NaN    NaN               NaN          NaN
# 1Kilo                      NaN   NaN    NaN               NaN          NaN
# 1ST VOWS                   NaN   NaN    NaN               NaN          NaN
# 2 Chainz                   NaN   NaN    NaN               NaN          NaN
# 2 Face T.R.E.              NaN   NaN    NaN               NaN          NaN
# 2 Mello                    NaN   NaN    NaN               NaN          NaN
# 20 Years of Age            NaN   NaN    NaN               NaN          NaN
# 21 Days                    NaN   NaN    NaN               NaN          NaN
# 21 Savage                  NaN   NaN    NaN               NaN          NaN
# 24hrs                      NaN   NaN    NaN               NaN          NaN
# 28mm                       NaN   NaN    NaN               NaN          NaN
# 2BiC                       NaN   NaN    NaN               NaN          NaN
# 2SCOOPS                    NaN   NaN    NaN               NaN          NaN
# ...                        ...   ...    ...               ...          ...
# Антон Беляев               NaN   NaN    NaN               NaN          NaN
# Григорий Лепс              NaN   NaN    NaN               NaN          NaN
# Дельфин                    NaN   NaN    NaN               NaN          NaN
# Джиган                     NaN   NaN    NaN               NaN          NaN
# Кино                       NaN   NaN    NaN               NaN          NaN
# Кровосток                  NaN   NaN    NaN               NaN          NaN
# Ленинград                  NaN   NaN    NaN               NaN          NaN
# Макс Барских               NaN   NaN    NaN               NaN          NaN
# Мари Краймбрери            NaN   NaN    NaN               NaN          NaN
# Михаил Шуфутинский         NaN   NaN    NaN               NaN          NaN
# Миша Марвин                NaN   NaN    NaN               NaN          NaN
# Мот                        NaN   NaN    NaN               NaN          NaN
# Мохито                     NaN   NaN    NaN               NaN          NaN
# Нюша                       NaN   NaN    NaN               NaN          NaN
# Эллаи                      NaN   NaN    NaN               NaN          NaN
# тпсб                       NaN   NaN    NaN               NaN          NaN
# 侯英祚                        NaN   NaN    NaN               NaN          NaN
# 湊貴大(流星P)                   NaN   NaN    NaN               NaN          NaN
# 緑                          NaN   NaN    NaN               NaN          NaN
# 霍尊                         NaN   NaN    NaN               NaN          NaN
# 니하고내하고                     NaN   NaN    NaN               NaN          NaN
# 박재정                        NaN   NaN    NaN               NaN          NaN
# 범키                         NaN   NaN    NaN               NaN          NaN
# 스텔라장                       NaN   NaN    NaN               NaN          NaN
# 유나                         NaN   NaN    NaN               NaN          NaN
# 유닛플러스                      NaN   NaN    NaN               NaN          NaN
# 임정희                        NaN  21.0    NaN               NaN          NaN
# 장재인                        NaN   NaN    NaN               NaN          NaN
# 하동균                        NaN   NaN    NaN               NaN          NaN
# ＮＯＳＴＲＡＤＡＭＵＳ                NaN   NaN    NaN               NaN          NaN
#
# track_name              항상 (HANGSANG)  후유증 Falling Blossoms
# artist_name
# !!!                               NaN                   NaN
# "Elena Of Avalor" Cast            NaN                   NaN
# "Weird Al" Yankovic               NaN                   NaN
# $hirak                            NaN                   NaN
# $tranger                          NaN                   NaN
# $tupid Young                      NaN                   NaN
# $uicideBoy$                       NaN                   NaN
# (G)I-DLE                          NaN                   NaN
# .anxious.                         NaN                   NaN
# 03 Greedo                         NaN                   NaN
# 070 Shake                         NaN                   NaN
# 100Gang                           NaN                   NaN
# 10cellphones                      NaN                   NaN
# 116                               NaN                   NaN
# 12Stone Worship                   NaN                   NaN
# 13 Block                          NaN                   NaN
# 13 Crowns                         NaN                   NaN
# 1:AM Beats                        NaN                   NaN
# 1Kilo                             NaN                   NaN
# 1ST VOWS                          NaN                   NaN
# 2 Chainz                          NaN                   NaN
# 2 Face T.R.E.                     NaN                   NaN
# 2 Mello                           NaN                   NaN
# 20 Years of Age                   NaN                   NaN
# 21 Days                           NaN                   NaN
# 21 Savage                         NaN                   NaN
# 24hrs                             NaN                   NaN
# 28mm                              NaN                   NaN
# 2BiC                              NaN                   NaN
# 2SCOOPS                           NaN                   NaN
# ...                               ...                   ...
# Антон Беляев                      NaN                   NaN
# Григорий Лепс                     NaN                   NaN
# Дельфин                           NaN                   NaN
# Джиган                            NaN                   NaN
# Кино                              NaN                   NaN
# Кровосток                         NaN                   NaN
# Ленинград                         NaN                   NaN
# Макс Барских                      NaN                   NaN
# Мари Краймбрери                   NaN                   NaN
# Михаил Шуфутинский                NaN                   NaN
# Миша Марвин                       NaN                   NaN
# Мот                               NaN                   NaN
# Мохито                            NaN                   NaN
# Нюша                              NaN                   NaN
# Эллаи                             NaN                   NaN
# тпсб                              NaN                   NaN
# 侯英祚                               NaN                   NaN
# 湊貴大(流星P)                          NaN                   NaN
# 緑                                 NaN                   NaN
# 霍尊                                NaN                   NaN
# 니하고내하고                            NaN                   NaN
# 박재정                               NaN                   NaN
# 범키                                NaN                   NaN
# 스텔라장                              NaN                   NaN
# 유나                                NaN                   NaN
# 유닛플러스                             NaN                   NaN
# 임정희                               NaN                   NaN
# 장재인                               NaN                   NaN
# 하동균                               NaN                   NaN
# ＮＯＳＴＲＡＤＡＭＵＳ                       NaN                   NaN
#
# [8041 rows x 12424 columns]

# %%
#print(dataset)
dataset.sort_values('popularity',ascending=False).head(10)
# Out:
#            artist_name                track_id  \
# 99366   Jonas Brothers  4y3OI86AEP6PQoDE6olYhO
# 101609           Ozuna  7uH27oIt4a6cIFCA8ZPcyG
# 123911        Lil Baby  78QR3Wp35dqAhFEc2qAGjE
# 99377    Billie Eilish  6IRdLKIyS4p7XNiP8r6rsx
# 123943     Mark Ronson  27rdGxbavYJeBphck5MZAF
# 123905           Drake  6DCZcSspjsKoFjzjrWoCdn
# 99396           Khalid  09oZ9eXQ2fo6YDrPzJqAoP
# 124113         Becky G  7dNwJbsT0sg1le5kVugGJb
# 124112   Calvin Harris  7ef4DlsgrMEH11cDZd32M6
# 123903    XXXTENTACION  7AFASza1mXqntmGtbxXprO
#
#                                              track_name  acousticness  \
# 99366                                            Sucker       0.04270
# 101609                                Baila Baila Baila       0.03610
# 123911                 Drip Too Hard (Lil Baby & Gunna)       0.10300
# 99377                     all the good girls go to hell       0.31600
# 123943  Nothing Breaks Like a Heart (feat. Miley Cyrus)       0.00987
# 123905                                       God's Plan       0.03320
# 99396                   Outta My Head (with John Mayer)       0.01740
# 124113                                           Bubalu       0.61600
# 124112                         One Kiss (with Dua Lipa)       0.03700
# 123903                                          changes       0.88300
#
#         danceability  duration_ms  energy  instrumentalness  key  liveness  \
# 99366          0.842       181040   0.734          0.000000    1    0.1060
# 101609         0.816       158400   0.754          0.000000   11    0.2170
# 123911         0.896       145543   0.671          0.000000    1    0.5520
# 99377          0.741       168840   0.447          0.121000    8    0.1870
# 123943         0.601       217467   0.794          0.000001    7    0.3880
# 123905         0.754       198973   0.449          0.000083    7    0.5520
# 99396          0.729       177067   0.545          0.000274    0    0.3690
# 124113         0.800       228493   0.355          0.000000    6    0.1180
# 124112         0.791       214847   0.862          0.000022    9    0.0814
# 123903         0.669       121887   0.308          0.000000   11    0.0984
#
#         loudness  mode  speechiness    tempo  time_signature  valence  \
# 99366     -5.065     0       0.0588  137.958               4    0.952
# 101609    -2.750     0       0.1110   99.966               4    0.533
# 123911    -6.977     0       0.2890  112.502               4    0.358
# 99377     -9.015     0       0.3880  184.980               4    0.551
# 123943    -5.844     0       0.0671  114.066               4    0.244
# 123905    -9.211     1       0.1090   77.169               4    0.357
# 99396     -7.818     1       0.0316  103.012               4    0.514
# 124113   -10.470     0       0.0895  145.929               4    0.253
# 124112    -3.240     0       0.1100  123.994               4    0.592
# 123903   -10.068     1       0.0290   64.934               4    0.520
#
#         popularity
# 99366           98
# 101609          95
# 123911          91
# 99377           91
# 123943          90
# 123905          89
# 99396           88
# 124113          88
# 124112          88
# 123903          87

# %%
dataset.sort_values('popularity',ascending=False).iloc[:,-1]
# Out:
# 99366     98
# 101609    95
# 123911    91
# 99377     91
# 123943    90
# 123905    89
# 99396     88
# 124113    88
# 124112    88
# 123903    87
# 123952    87
# 123932    87
# 101791    86
# 124099    86
# 124192    86
# 124116    86
# 120792    85
# 124100    85
# 99392     85
# 101706    85
# 124209    84
# 124105    84
# 101709    84
# 123886    84
# 124149    84
# 123912    83
# 123963    83
# 124370    83
# 95900     83
# 101712    83
#           ..
# 105864     0
# 61138      0
# 106937     0
# 14679      0
# 17350      0
# 99444      0
# 24614      0
# 22808      0
# 86515      0
# 9705       0
# 31882      0
# 31106      0
# 54360      0
# 80076      0
# 48129      0
# 112249     0
# 34401      0
# 24912      0
# 25275      0
# 29778      0
# 35376      0
# 82845      0
# 73927      0
# 51239      0
# 62858      0
# 13663      0
# 26724      0
# 30718      0
# 84674      0
# 81454      0
# Name: popularity, Length: 13066, dtype: int64

# %%
#musicdata
#JonasBrothers_music_popularity = musicdata['Sucker']
#Ozuna_music_popularity = musicdata['Baila Baila Baila']
#JonasBrothers_music_popularity
JonasBrothers_music_popularity=dataset.loc[dataset['track_name'] =='Bubalu' ]
Ozuna_music_popularity=dataset.loc[dataset['track_name'] =='Baila Baila Baila' ]
JonasBrothers_music_popularity
Ozuna_music_popularity
# Out:
#        artist_name                track_id         track_name  acousticness  \
# 101609       Ozuna  7uH27oIt4a6cIFCA8ZPcyG  Baila Baila Baila        0.0361
#
#         danceability  duration_ms  energy  instrumentalness  key  liveness  \
# 101609         0.816       158400   0.754               0.0   11     0.217
#
#         loudness  mode  speechiness   tempo  time_signature  valence  \
# 101609     -2.75     0        0.111  99.966               4    0.533
#
#         popularity
# 101609          95

# %%
p=JonasBrothers_music_popularity['popularity']
pp=int(p)
sim_Sucker=dataset.loc[dataset['popularity'] ==pp]
print(sim_Sucker)
#similar_to_Sucker = musicdata.corrwith(JonasBrothers_music_popularity)
#similar_to_Baila_Baila_Baila = musicdata.corrwith(Ozuna_music_popularity)
#print(similar_to_Sucker)
# Out:
#           artist_name                track_id  \
# 124112  Calvin Harris  7ef4DlsgrMEH11cDZd32M6
# 124113        Becky G  7dNwJbsT0sg1le5kVugGJb
# 99396          Khalid  09oZ9eXQ2fo6YDrPzJqAoP
#
#                              track_name  acousticness  danceability  \
# 124112         One Kiss (with Dua Lipa)        0.0370         0.791
# 124113                           Bubalu        0.6160         0.800
# 99396   Outta My Head (with John Mayer)        0.0174         0.729
#
#         duration_ms  energy  instrumentalness  key  liveness  loudness  mode  \
# 124112       214847   0.862          0.000022    9    0.0814    -3.240     0
# 124113       228493   0.355          0.000000    6    0.1180   -10.470     0
# 99396        177067   0.545          0.000274    0    0.3690    -7.818     1
#
#         speechiness    tempo  time_signature  valence  popularity
# 124112       0.1100  123.994               4    0.592          88
# 124113       0.0895  145.929               4    0.253          88
# 99396        0.0316  103.012               4    0.514          88

# %%
corr_Sucker = pd.DataFrame(similar_to_Sucker,columns=['popularity'])
corr_Sucker.dropna(inplace=True)
corr_Sucker.head(10)
# Out:
# Empty DataFrame
# Columns: [popularity]
# Index: []

# %%
corr_starwars.sort_values('popularity',ascending=False).head(10)
#corr_starwars = corr_starwars.join(ratings['num of ratings'])
corr_starwars.head()
# Out:
# Empty DataFrame
# Columns: [popularity]
# Index: []

# %%
corr_starwars = corr_starwars.join(popularity['popularity'])
corr_starwars.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-8f668b166d32> in <module>
# ----> 1 corr_starwars = corr_starwars.join(popularity['popularity'])
#       2 corr_starwars.head()
#
# NameError: name 'popularity' is not defined

# %%
corr_starwars[corr_starwars['num of ratings']>100].sort_values('Correlation',ascending=False).head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'num of ratings'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-46-f7bfcd9a3495> in <module>
# ----> 1 corr_starwars[corr_starwars['num of ratings']>100].sort_values('Correlation',ascending=False).head()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'num of ratings'

# %%
corr_liarliar = pd.DataFrame(similar_to_liarliar,columns=['Correlation'])
corr_liarliar.dropna(inplace=True)
corr_liarliar = corr_liarliar.join(ratings['num of ratings'])
corr_liarliar[corr_liarliar['num of ratings']>100].sort_values('Correlation',ascending=False).head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-28ce8509d66d> in <module>
# ----> 1 corr_liarliar = pd.DataFrame(similar_to_liarliar,columns=['Correlation'])
#       2 corr_liarliar.dropna(inplace=True)
#       3 corr_liarliar = corr_liarliar.join(ratings['num of ratings'])
#       4 corr_liarliar[corr_liarliar['num of ratings']>100].sort_values('Correlation',ascending=False).head()
#
# NameError: name 'similar_to_liarliar' is not defined
